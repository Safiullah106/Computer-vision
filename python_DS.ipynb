# %% [markdown]
# <a href="https://colab.research.google.com/github/Safiullah106/Computer-vision/blob/main/python_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(type("Helo world"))
print(type(5))
print(type(2.5))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
name ="Ali"
age = 25
cgpa = 3.5
print(name, age, cgpa)
print(type(name), type(age), type(cgpa))
# Out:
# Ali 25 3.5
# <class 'str'> <class 'int'> <class 'float'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# Input Method

# %%
name = input("Enter your name: ")
print("Your name is", name)
# Out:
# Enter your name: Ali
# Your name is Ali

# %%
age = int(input("Enter your name: "))
print("Your name is", age)
# Out:
# Enter your name: 25
# Your name is 25

# %%
num1 = int(input("Enter number 1: "))
num2 = int(input("Enter number 2: "))
sum = num1+num2
print(sum)
# Out:
# Enter number 1: 2
# Enter number 2: 2
# 4

# %%
num1 = float(input("Enter number 1: "))
num2 = float(input("Enter number 2: "))
sum = num1+num2/2
print(sum)
# Out:
# Enter number 1: 2.5
# Enter number 2: 2.5
# 3.75

# %%
name = input("Enter name: ")
city = input("Enter City:")
print("Name: ", name)
print("City: ", city )
# Out:
# Enter name: ali
# Enter City:layyah
# Name:  ali
# City:  layyah

# %%
name, city = input("Enter name and city: ").split()

print("Name: ", name)
print("City: ", city )
# Out:
# Enter name and city: ali layyah
# Name:  ali
# City:  layyah

# %%
x=42
y=2
z=10
print(id(x), id(y), id(z))

print(x is y)

print(x==y)

a=1000
b=1000
print(a is b)
# Out:
# 10447720 10446440 10446696
# False
# False
# False

# %%
a = [1,2,3]
b=a
b.append(4)
print(a)

c= a.copy()
c.append(5)
print(a)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
nums = [4,8,15,16,23,42]
print(nums[0])
print(nums[5])
# Out:
# 4
# 42

# %%
x = 10
old=id(x)
x = x + 5
new_id=id(x)
print(old, new_id)
print(old==new_id)
# Out:
# 10446696 10446856
# False

# %%
x = 10

x = x + 5

print(id(x), id(x))
print(x==x)
# Out:
# 10446856 10446856
# True

# %%
my_list = [10, 20, 30]
my_tuple = (10, 20, 30)
my_list[0] = 100
print(my_list)
# Out:
# [100, 20, 30]

# %%
x=10
old=id(x)
x=x+20
new_id=id(x)
print(old, new_id)
# Out:
# 10446696 10447336

# %%
a =[1,2,3]
b=a
b.append(4)
print(a)

c=a.copy()
c.append(5)
print(a)
print(id(a), id(b), id(c))
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]
# 132371470705024 132371470705024 132371466670464

# %%
def increment(n):
  n+=1
  return n

  def add_item(items):

    x=5

    increment(x)
    print(x)

    cart =["apple", "bread"]
    add_item(cart)

    print(cart)

# %%
def increment(n):
    n += 1
    return n


def add_item(items):
    items.append("milk")


x = 5

increment(x)
print(x)

cart = ["apple", "bread"]

add_item(cart)

print(cart)
# Out:
# 5
# ['apple', 'bread', 'milk']

# %%
def add_item(item, cart=None):
  if cart is None:
    cart=[]
    cart.append(item)
    return cart
    print(cart)

# %%
def add_item(item, cart=[]):
    cart.append(item)
    return cart

print(add_item("Apple"))
print(add_item("Bread"))
print(add_item("Milk"))
# Out:
# ['Apple']
# ['Apple', 'Bread']
# ['Apple', 'Bread', 'Milk']

# %%
def add_item(item, cart=None):
    if cart is None:
        cart = []

    cart.append(item)
    return cart

print(add_item("Apple"))
print(add_item("Bread"))
print(add_item("Milk"))
# Out:
# ['Apple']
# ['Bread']
# ['Milk']

# %%
def add_item(item, cart=None):
    if cart is None:
        cart = []

    cart.append(item)
    return cart

cart = ["Apple"]

print(add_item("Bread", cart))
print(add_item("Milk", cart))
print(cart)
# Out:
# ['Apple', 'Bread']
# ['Apple', 'Bread', 'Milk']
# ['Apple', 'Bread', 'Milk']
